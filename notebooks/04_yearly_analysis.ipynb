# %% [markdown]
# # Yearly average analysis
# In this notebook, we compute yearly performance metrics.

# %% [markdown]
# ## Load data
# Load data from the CSV files computed using the prepare_data.py script.

# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
from src.plots import plot_yearly_metric

yearly_summary = pd.read_csv("../output/yearly_summary.csv")

# %% [markdown]
# ## Graphs
# ### Nights per year

# %%
plot_yearly_metric(
    yearly_summary, 
    'occupied_nights', 
    title="Occupied nights", 
    y_label="Nights"
)

# %% [markdown]
# ### Occupancy rate

# %%
plot_yearly_metric(
    yearly_summary, 
    'occupancy_pct', 
    title="Occupancy", 
    y_label="Occuancy (%)"
)

# %% [markdown]
# ### Average number of persons per night

# %%
plot_yearly_metric(
    yearly_summary, 
    'avg_persons', 
    title="Average persons per night", 
    y_label="Persons",
    ylim=(1,2)
)

# %% [markdown]
# ### Average daily earnings (net)

# %%
plot_yearly_metric(
    yearly_summary, 
    'avg_price', 
    title="Average net earnings per night", 
    y_label="Euro (€)",
)

# %% [markdown]
# ### Yearly earnings (net)

# %%
plot_yearly_metric(
    yearly_summary, 
    'yearly_revenue', 
    title="Revenue", 
    y_label="Euro (€)",
)
